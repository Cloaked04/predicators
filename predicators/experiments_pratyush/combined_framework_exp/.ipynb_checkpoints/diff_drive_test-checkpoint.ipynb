# %%
import sys
import numpy as np
import pybullet as p
import time
import logging
from typing import List, Tuple, Optional, Sequence, Collection, Dict, Any, cast
import random
import json
import ipdb

from predicators.structs import Action, Array, GroundAtom, Object, State, Type, ParameterizedOption
from predicators import utils
from predicators.settings import CFG
from gym.spaces import Box

#Import core environment methods, robot function etc.

from predicators.envs.pybullet_blocks import PyBulletBlocksEnv
from predicators.envs.pybullet_env import PyBulletEnv, create_pybullet_block
from predicators.pybullet_helpers.robots import SingleArmPyBulletRobot
from predicators.pybullet_helpers.robots.mobile_single_arm import MobileSingleArmPyBulletRobot
from predicators.pybullet_helpers.geometry import Pose
from predicators.pybullet_helpers.joint import JointPositions, get_joint_infos, get_joint_positions
from predicators.pybullet_helpers.link import get_link_state, get_link_pose

#Import the functions that are to be tested:

from predicators.pybullet_helpers.motion_planning import run_motion_planning, run_base_motion_planning,\
                                                            run_coordinated_motion_planning
#The pick/place options to be tested are accessed via the env instance
from predicators.pybullet_helpers.controllers import execute_coordinated_path, create_move_end_effector_to_pose_option,\
                                                    create_change_fingers_option, create_move_base_option
#Configure logging for better debugging outputs:
#logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.basicConfig(
    level=logging.WARNING,                    
    format="%(asctime)s %(name)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# %%
#Defining test configuration, and overriding some default ones:
CFG.pybullet_robot = "fetch_mobile"
CFG.use_gui = True
#Draws helpful debug lines in the workspace.
#NOT SURE WHETHER TO USE THIS. WILL DECIDE AFTER A COUPLE RUNS.
#CFG.pybullet_draw_debug = True
#Initializing with standard size of blocks.
CFG.blocks_block_size = 0.05
CFG.pybullet_birrt_num_iters = 50
CFG.pybullet_birrt_num_attempts = 10
CFG.pybullet_birrt_smooth_amt = 20
CFG.seed = random.randint(0,10000)
#CFG.seed = 12
#Num of PyBullet physics steps per high-level Action in visualize_action_sequence
CFG.pybullet_sim_steps_per_action = 120

# %%
#Function to reset robot to a known pose
def reset_robot_fetch_mobile(robot: MobileSingleArmPyBulletRobot,
                             physics_client_id:int,
                             base_pose: Tuple[float, float, float] = (1.35, 0.75, 0.0), # (x,y,theta)
                             arm_joint_angle: Optional[List[float]]=None):
    """
    Resets the robot's base/ teleports it and arm to specified poses.

    """

    robot.move_base_to(base_pose, physics_client_id)
    if arm_joint_angle:
        #Set arm joints only
        robot.set_joints(arm_joint_angle)
    else:
        #robot.initial_joint_positions includes arm and finger joints
        robot.set_joints(robot.initial_joint_positions)
    #Step simulation a bit to allow PyBullet to settle the state.
    for _ in range(10):
        p.stepSimulation(physicsClientId=physics_client_id)


#Fn to create blocks in the env.
def create_test_block(env: PyBulletEnv,
                      pose: Tuple[float, float, float],
                      color: Tuple[float, float, float, float] = (0.8, 0.2, 0.2, 1.0),
                      name_suffix: str = "test") -> int:
    """
    Creates a single block at a specified pose for testing and returns its PyBullet ID.
    """

    #Use the fn defined in utils to create block
    block_id = create_pybullet_block(
        color,
        (CFG.blocks_block_size/2,)*3,
        env._obj_mass,
        env._obj_friction,
        env._default_orn,
        env._physics_client_id
    )
    #Place the block at desired pose.
    p.resetBasePositionAndOrientation(block_id, pose, env._default_orn, physicsClientId=env._physics_client_id)

    return block_id


#Get the list of all bodies except the robot.
#TODO: Need to add logic that saves object/body name
#      which can be used for better debugging with collision.
def get_all_non_robot_bodies(robot_id: int, physics_client_id:int) -> List[int]:
    """
    Gets all PyBullet body IDs in the simulation except for the robot itself.
    These are typically used as collision obstacles.
    """
    all_bodies = [p.getBodyUniqueId(i, physicsClientId=physics_client_id)
                    for i in range(p.getNumBodies(physicsClientId=physics_client_id))]


    return [b for b in all_bodies if b!=robot_id]

# %%
#Setup Env.
#Initialize the PyBulletBlocksEnv which sets up PyBullet,
#loads the robot, tables etc.

env = PyBulletBlocksEnv(use_gui=CFG.use_gui)
# Out:
# /home/cloaked04/anaconda3/envs/predicators/lib/python3.10/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
 # Resets the environment to a specific task, getting an initial symbolic state.
# While initial_state_from_env is fetched, the option tests will create their own
# more specific symbolic states.
initial_state = env.reset("train", 0)

# The robot instance from the environment
robot = env._pybullet_robot
# The PyBullet physics client ID
physics_client_id = env._physics_client_id

if not isinstance(robot, MobileSingleArmPyBulletRobot):
    logging.error("This test script is designed for a MobileSingleArmPyBulletRobot.")

# dyn = p.getDynamicsInfo(robot.robot_id, -1, physicsClientId=env._physics_client_id)
# print(f"\nMass, inertialFrame…{dyn}")
# input()


logging.info(f"Using robot: {robot.get_name()}")


#Store the robot's default arm and finger joint positions.
home_arm_joints = robot.initial_joint_positions

robot_obj = initial_state.get_objects(env._robot_type)[0]

#Store permament, fixed bodies
static_collision_bodies = get_all_non_robot_bodies(robot.robot_id, physics_client_id)

#print(f"Static_collision_bodies:{static_collision_bodies}")

#sys.exit(0)

#Define a rectangular workspace for base motion planning tests.
#(min_x, min_y, max_x, max_y)
workspace_bounds = (1.0, 0.2, 1.7, 1.3)

# %%
initial_base_pose = (0.4, 1.6, -np.pi/2)
target_base_pose = (0.75, 0.7441, np.pi / 4) # Target base pose
logging.info(f"Testing base-only motion from {initial_base_pose} to {target_base_pose}...")

#Resetting robot's state:
robot.move_base_to(initial_base_pose, physics_client_id)
robot.set_joints(home_arm_joints)

#Step simulation a bit to allow PyBullet to settle the state.
for _ in range(20):
    p.stepSimulation(physicsClientId=physics_client_id)

# %%
home_orn = env.get_robot_ee_home_orn()
# Keeping the z a bit high to avoid collision:
z = env.table_height + CFG.blocks_block_size/2 + 0.01
#logging.critical(f"Value of z: {z}.")
orn = (0, 0.7071, 0, 0.7071)

target_ee_pose = Pose(position=(1.5 , 0.75, z), 
                         orientation=home_orn)

coordinated_path = run_coordinated_motion_planning(
    robot,
    target_ee_pose=target_ee_pose,
    collision_bodies=static_collision_bodies,
    seed=CFG.seed,
    physics_client_id=physics_client_id,
    try_arm_only_first=True # Planner will try arm-only, fail, then try base+arm
)

base_path_waypoints, arm_path_waypoints = coordinated_path
# Out:
# 2025-08-10 22:22:18 root [WARNING] Max time reached. No IKFast solution found.
# 2025-08-10 22:22:18 root [WARNING] No IK solutions found in 0.501 seconds
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING]
#  Collsion check:COLLIDES :-(
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING] Planning arm motion to above target.
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING] Length of path to above target: 21.
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING] IK to move down succeeeded.
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING] Planning to move EE down to target.
# 2025-08-10 22:22:18 predicators.pybullet_helpers.motion_planning [WARNING] Length of path to move down to target: 61.
# Coordinated Planning: Arm-only IK failed. Moving to base planning.

# %%
# def preprocess_path_for_differential_drive(  
#     raw_path: List[Tuple[float, float, float]],  
#     position_threshold: float = 0.05,  
#     rotation_threshold: float = 0.1  
# ) -> List[Tuple[float, float, float]]:  
#     """  
#     Preprocess BiRRT path to separate rotation and translation phases.  
#     This mimics iGibson's three-phase motion planning approach.  
#     """  
#     if len(raw_path) < 2:  
#         return raw_path  
      
#     processed_path = [raw_path[0]]  # Start with initial pose  
      
#     for i in range(1, len(raw_path)):  
#         prev_pose = processed_path[-1]  
#         curr_pose = raw_path[i]  
          
#         x1, y1, theta1 = prev_pose  
#         x2, y2, theta2 = curr_pose  
          
#         # Calculate position and orientation differences  
#         dx, dy = x2 - x1, y2 - y1  
#         position_dist = np.sqrt(dx*dx + dy*dy)  
          
#         # Calculate target heading for translation  
#         target_heading = np.arctan2(dy, dx) if position_dist > 0.01 else theta1  
          
#         # Circular difference for angles  
#         def circular_diff(a1, a2):  
#             diff = a1 - a2  
#             while diff > np.pi: diff -= 2 * np.pi  
#             while diff < -np.pi: diff += 2 * np.pi  
#             return diff  
          
#         heading_diff = abs(circular_diff(target_heading, theta1))  
#         final_diff = abs(circular_diff(theta2, target_heading))  
          
#         # Phase 1: Rotate to face target direction (if needed)  
#         if heading_diff > rotation_threshold and position_dist > position_threshold:  
#             processed_path.append((x1, y1, target_heading))  
          
#         # Phase 2: Translate while maintaining heading (if needed)  
#         if position_dist > position_threshold:  
#             processed_path.append((x2, y2, target_heading))  
          
#         # Phase 3: Rotate to final orientation (if needed)  
#         if final_diff > rotation_threshold:  
#             processed_path.append((x2, y2, theta2))  
#         elif position_dist <= position_threshold:  
#             # Just orientation change  
#             processed_path.append((x2, y2, theta2))  
      
#     return processed_path 

# base_path_waypoints = preprocess_path_for_differential_drive(raw_path=base_path_waypoints)

# %%
base_path_waypoints
# Out:
# [(0.4, 1.6, -1.5707963267948963),
#  (0.4, 1.6, -1.5707963267948963),
#  (0.4, 1.6, -1.521907620869269),
#  (0.4, 1.6, -1.4730189149436417),
#  (0.4, 1.6, -1.4241302090180143),
#  (0.4, 1.6, -1.375241503092387),
#  (0.4, 1.6, -1.3263527971667597),
#  (0.4, 1.6, -1.2774640912411326),
#  (0.4, 1.6, -1.2285753853155053),
#  (0.4, 1.6, -1.179686679389878),
    Remove duplicate waypoints (anywhere in list, not just consecutive) 
    while preserving original order.
    """
    unique = []
    seen = set()
    for w in waypoints:
        # Round to tolerance to avoid floating-point issues
        key = tuple(round(v / tol) for v in w)
        if key not in seen:
            seen.add(key)
            unique.append(w)
    return unique

# %%
cleaned_base_path = deduplicate_waypoints(base_path_waypoints)

# %%
cleaned_base_path
# Out:
# [(0.4, 1.6, -1.5707963267948963),
#  (0.4, 1.6, -1.521907620869269),
#  (0.4, 1.6, -1.4730189149436417),
#  (0.4, 1.6, -1.4241302090180143),
#  (0.4, 1.6, -1.375241503092387),
#  (0.4, 1.6, -1.3263527971667597),
#  (0.4, 1.6, -1.2774640912411326),
#  (0.4, 1.6, -1.2285753853155053),
#  (0.4, 1.6, -1.179686679389878),
#  (0.4, 1.6, -1.1307979734642506),
#  (0.4, 1.6, -1.0819092675386233),
#  (0.4, 1.6, -1.033020561612996),
#  (0.4, 1.6, -0.9841318556873686),
#  (0.4, 1.6, -0.9352431497617413),
#  (0.4, 1.6, -0.8863544438361141),
#  (0.4, 1.6, -0.8374657379104866),
#  (0.4, 1.6, -0.7885770319848594),
#  (0.4, 1.6, -0.7396883260592321),
#  (0.4, 1.6, -0.6907996201336047),
#  (0.4, 1.6, -0.6419109142079774),
#  (0.4, 1.6, -0.5930222082823502),
#  (0.4, 1.6, -0.5441335023567226),
#  (0.4, 1.6, -0.49524479643109554),
#  (0.4, 1.6, -0.4463560905054682),
#  (0.4, 1.6, -0.3974673845798409),
#  (0.4, 1.6, -0.34857867865421355),
#  (0.4, 1.6, -0.2996899727285862),
#  (0.4, 1.6, -0.2508012668029589),
#  (0.4, 1.6, -0.20191256087733178),
#  (0.4, 1.6, -0.15302385495170423),
#  (0.4, 1.6, -0.1041351490260769),
#  (0.4, 1.6, -0.055246443100449794),
#  (0.4, 1.6, -0.006357737174822464),
#  (0.4, 1.6, 0.04253096875080509),
#  (0.4, 1.6, 0.0914196746764322),
#  (0.4, 1.6, 0.14030838060205952),
#  (0.4, 1.6, 0.18919708652768685),
#  (0.4, 1.6, 0.23808579245331418),
#  (0.4, 1.6, 0.2869744983789415),
#  (0.44988243211332934, 1.6147213445456137, 0.2869744983789415),
#  (0.49976486422665867, 1.6294426890912272, 0.2869744983789415),
#  (0.549647296339988, 1.6441640336368408, 0.2869744983789415),
#  (0.5995297284533173, 1.6588853781824546, 0.2869744983789415),
#  (0.6494121605666466, 1.6736067227280682, 0.2869744983789415),
#  (0.699294592679976, 1.6883280672736818, 0.2869744983789415),
#  (0.7491770247933053, 1.7030494118192954, 0.2869744983789415),
#  (0.7990594569066346, 1.717770756364909, 0.2869744983789415),
#  (0.8489418890199639, 1.7324921009105227, 0.2869744983789415),
#  (0.8988243211332932, 1.7472134454561363, 0.2869744983789415),
#  (0.9487067532466226, 1.76193479000175, 0.2869744983789415),
#  (0.9985891853599519, 1.7766561345473635, 0.2869744983789415),
#  (1.048471617473281, 1.791377479092977, 0.2869744983789415),
#  (1.0983540495866104, 1.8060988236385906, 0.2869744983789415),
#  (1.9127353045785223, 0.14659924838695948, 1.7751599408904046),
#  (1.9127353045785223, 0.14659924838695948, 1.8246041365633587),
#  (1.9127353045785223, 0.14659924838695948, 1.8740483322363128),
#  (1.9127353045785223, 0.14659924838695948, 1.9234925279092667),
#  (1.9127353045785223, 0.14659924838695948, 1.9729367235822208),
#  (1.9127353045785223, 0.14659924838695948, 2.0223809192551747),
#  (1.9127353045785223, 0.14659924838695948, 2.071825114928129),
#  (1.9127353045785223, 0.14659924838695948, 2.121269310601083),
#  (1.9127353045785223, 0.14659924838695948, 2.170713506274037)]

# %%
def get_current_base_and_arm_pose(robot, state:State, objects: Sequence[Object], params: Array):

    current_base_pose = robot.get_base_pose(physics_client_id)
    current_joint_positions = robot.get_joints()

    return current_base_pose, current_joint_positions

target_base_pose = base_path_waypoints[-1]

move_option_memory = {}
param_space = Box(low=np.array([], dtype=np.float32),
                  high=np.array([], dtype=np.float32), dtype=np.float32)

move_option = create_move_base_option(robot, name="diff-drive",types=[env._robot_type], params_space=param_space,
                                    get_current_base_and_arm_pose=get_current_base_and_arm_pose, base_path=cleaned_base_path,
                                    target_base_pose = target_base_pose)


#The empty nd array is the empty param space that this option takes in as all
#the values are passed in to the option creation function. If this were to change,
#values will be passed in this array, and assigned to appropricate vars in _initialble
#and the param_space Box size will be changed accordingly.
grounded_move = move_option.ground([robot_obj], np.array([], dtype=np.float32))

# %%
assert grounded_move.initiable(move_option_memory)

print(grounded_move)

state = initial_state

while not grounded_move.terminal(move_option_memory):
    action = grounded_move.policy(move_option_memory)
    #logging.warning(f"\nNext action to be simulated:{action}.")
    #state = env.simulate(initial_state, action)

    #omega_r, omega_l = action.base_motion
    vel, omega = action.base_motion['params']

    # print(f"\nWheel velocities: {omega_r, omega_l}.")
    # input()

    #robot.set_wheel_motors(omega_r, omega_l, physics_client_id)
    # X, Y, THETA = robot.get_base_pose(physics_client_id)
    # vx, vy = 0.3 * np.cos(THETA), 0.3 * np.sin(THETA)
    # p.resetBaseVelocity(
    #     robot.robot_id,
    #     linearVelocity  = [vx, vy, 0.0],
    #     angularVelocity = [0.0, 0.0, omega],
    #     physicsClientId = physics_client_id)

    robot.set_wheel_motors(robot, vel, omega, physics_client_id)

    fixed_arm_pos = action.arr
    robot.set_motors(fixed_arm_pos)

    for _ in range(30):
        p.stepSimulation(physicsClientId=physics_client_id)
    time.sleep(0.05)

    # try:
    #     joint_solution = robot.inverse_kinematics(
    #             target_ee_pose, validate=True, set_joints=False)

    #     if joint_solution is not None:
    #         break

    # except:
    #     continue

    '''
    Now chain arm motion planning with this:
        - convert run_motion_planning to a singleParameterizedOption
        - connect to diff drive
    '''

# for waypoint in arm_path_waypoints:
#     action = Action(np.zeros(len(robot.action_space.low), dtype=float))
#     action._arr = waypoint

#     robot.set_motors(action.arr)
#     robot.set_wheel_motors(robot, 0.0, 0.0, physics_client_id)



print(f"\n Robot at {robot.get_base_pose(physics_client_id)} after executing differential drive.")
# Out:
# _Option(name='diff-drive', objects=[robby:robot], params=array([], dtype=float32))
# [DBG] d=2.120  br=far  ptr=0  look=25  α_W=1.57  α_G=0.80  dead=None  v=0.40  ω=3.20
# [DBG] d=2.099  br=far  ptr=0  look=25  α_W=2.64  α_G=0.46  dead=None  v=0.40  ω=1.55
# [DBG] d=2.091  br=far  ptr=0  look=25  α_W=2.56  α_G=0.39  dead=None  v=0.40  ω=1.76
# [DBG] d=2.084  br=far  ptr=0  look=25  α_W=2.48  α_G=0.33  dead=None  v=0.40  ω=1.97
# [DBG] d=2.076  br=far  ptr=0  look=25  α_W=2.31  α_G=0.22  dead=None  v=0.40  ω=2.36
# [DBG] d=2.061  br=far  ptr=0  look=25  α_W=2.23  α_G=0.11  dead=None  v=0.40  ω=2.52
# [DBG] d=2.043  br=far  ptr=0  look=25  α_W=2.16  α_G=-0.03  dead=None  v=0.40  ω=2.66
# [DBG] d=2.022  br=far  ptr=0  look=25  α_W=2.07  α_G=-0.18  dead=None  v=0.40  ω=2.81
# [DBG] d=1.998  br=far  ptr=0  look=25  α_W=1.98  α_G=-0.34  dead=None  v=0.40  ω=2.93
# [DBG] d=1.973  br=far  ptr=0  look=25  α_W=1.90  α_G=-0.52  dead=None  v=0.40  ω=3.03
# [DBG] d=1.947  br=far  ptr=0  look=25  α_W=1.83  α_G=-0.70  dead=None  v=0.40  ω=3.10
# [DBG] d=1.918  br=far  ptr=0  look=25  α_W=1.74  α_G=-0.89  dead=None  v=0.40  ω=3.15
# [DBG] d=1.894  br=far  ptr=0  look=25  α_W=1.65  α_G=-1.08  dead=None  v=0.40  ω=3.19
# [DBG] d=1.872  br=far  ptr=0  look=25  α_W=1.55  α_G=-1.28  dead=None  v=0.40  ω=3.20
# [DBG] d=1.855  br=far  ptr=0  look=25  α_W=1.46  α_G=-1.47  dead=None  v=0.40  ω=3.18
# [DBG] d=1.843  br=far  ptr=0  look=25  α_W=1.37  α_G=-1.65  dead=None  v=0.40  ω=3.13
# [DBG] d=1.836  br=far  ptr=0  look=25  α_W=1.28  α_G=-1.83  dead=None  v=0.40  ω=3.07
# [DBG] d=1.832  br=far  ptr=0  look=25  α_W=1.20  α_G=-2.01  dead=None  v=0.40  ω=2.98
# [DBG] d=1.833  br=far  ptr=0  look=25  α_W=1.12  α_G=-2.18  dead=None  v=0.40  ω=2.88
# [DBG] d=1.837  br=far  ptr=0  look=25  α_W=1.04  α_G=-2.36  dead=None  v=0.40  ω=2.76
# [DBG] d=1.845  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.51  dead=None  v=0.40  ω=2.65
# [DBG] d=1.856  br=far  ptr=0  look=25  α_W=0.92  α_G=-2.67  dead=None  v=0.40  ω=2.55
# [DBG] d=1.868  br=far  ptr=0  look=25  α_W=0.88  α_G=-2.80  dead=None  v=0.40  ω=2.46
# [DBG] d=1.883  br=far  ptr=0  look=25  α_W=0.82  α_G=-2.95  dead=None  v=0.40  ω=2.34
# [DBG] d=1.897  br=far  ptr=0  look=25  α_W=0.76  α_G=-3.09  dead=None  v=0.40  ω=2.21
# [DBG] d=1.915  br=far  ptr=0  look=25  α_W=0.73  α_G=3.06  dead=None  v=0.40  ω=2.12
# [DBG] d=1.929  br=far  ptr=0  look=25  α_W=0.70  α_G=2.97  dead=None  v=0.40  ω=2.06
# [DBG] d=1.948  br=far  ptr=0  look=25  α_W=0.66  α_G=2.84  dead=None  v=0.40  ω=1.95
# [DBG] d=1.962  br=far  ptr=0  look=25  α_W=0.63  α_G=2.77  dead=None  v=0.40  ω=1.89
# [DBG] d=1.981  br=far  ptr=0  look=25  α_W=0.60  α_G=2.65  dead=None  v=0.40  ω=1.80
# [DBG] d=1.994  br=far  ptr=0  look=25  α_W=0.58  α_G=2.59  dead=None  v=0.40  ω=1.76
# [DBG] d=2.012  br=far  ptr=0  look=25  α_W=0.55  α_G=2.48  dead=None  v=0.40  ω=1.66
# [DBG] d=2.028  br=far  ptr=0  look=25  α_W=0.53  α_G=2.41  dead=None  v=0.40  ω=1.62
# [DBG] d=2.042  br=far  ptr=0  look=25  α_W=0.52  α_G=2.34  dead=None  v=0.40  ω=1.59
# [DBG] d=2.055  br=far  ptr=0  look=25  α_W=0.51  α_G=2.29  dead=None  v=0.40  ω=1.56
# [DBG] d=2.070  br=far  ptr=0  look=25  α_W=0.50  α_G=2.22  dead=None  v=0.40  ω=1.53
# [DBG] d=2.080  br=far  ptr=0  look=25  α_W=0.49  α_G=2.17  dead=None  v=0.40  ω=1.50
# [DBG] d=2.091  br=far  ptr=0  look=25  α_W=0.48  α_G=2.12  dead=None  v=0.40  ω=1.47
# [DBG] d=2.102  br=far  ptr=0  look=25  α_W=0.47  α_G=2.06  dead=None  v=0.40  ω=1.45
# [DBG] d=2.111  br=far  ptr=0  look=25  α_W=0.46  α_G=2.01  dead=None  v=0.40  ω=1.41
# [DBG] d=2.122  br=far  ptr=0  look=25  α_W=0.45  α_G=1.96  dead=None  v=0.40  ω=1.39
# [DBG] d=2.128  br=far  ptr=0  look=25  α_W=0.44  α_G=1.92  dead=None  v=0.40  ω=1.36
# [DBG] d=2.138  br=far  ptr=0  look=25  α_W=0.43  α_G=1.87  dead=None  v=0.40  ω=1.34
# [DBG] d=2.145  br=far  ptr=0  look=25  α_W=0.43  α_G=1.83  dead=None  v=0.40  ω=1.32
# [DBG] d=2.152  br=far  ptr=0  look=25  α_W=0.42  α_G=1.78  dead=None  v=0.40  ω=1.31
# [DBG] d=2.158  br=far  ptr=0  look=25  α_W=0.41  α_G=1.74  dead=None  v=0.40  ω=1.28
# [DBG] d=2.164  br=far  ptr=0  look=25  α_W=0.41  α_G=1.70  dead=None  v=0.40  ω=1.27
# [DBG] d=2.169  br=far  ptr=0  look=25  α_W=0.40  α_G=1.66  dead=None  v=0.40  ω=1.25
# [DBG] d=2.174  br=far  ptr=0  look=25  α_W=0.40  α_G=1.62  dead=None  v=0.40  ω=1.25
# [DBG] d=2.179  br=far  ptr=0  look=25  α_W=0.40  α_G=1.59  dead=None  v=0.40  ω=1.25
# [DBG] d=2.184  br=far  ptr=0  look=25  α_W=0.40  α_G=1.55  dead=None  v=0.40  ω=1.25
# [DBG] d=2.188  br=far  ptr=0  look=25  α_W=0.41  α_G=1.51  dead=None  v=0.40  ω=1.26
# [DBG] d=2.193  br=far  ptr=0  look=25  α_W=0.41  α_G=1.47  dead=None  v=0.40  ω=1.27
# [DBG] d=2.197  br=far  ptr=0  look=25  α_W=0.42  α_G=1.43  dead=None  v=0.40  ω=1.29
# [DBG] d=2.202  br=far  ptr=0  look=25  α_W=0.43  α_G=1.39  dead=None  v=0.40  ω=1.33
# [DBG] d=2.206  br=far  ptr=0  look=25  α_W=0.44  α_G=1.35  dead=None  v=0.40  ω=1.37
# [DBG] d=2.210  br=far  ptr=0  look=25  α_W=0.46  α_G=1.30  dead=None  v=0.40  ω=1.43
# [DBG] d=2.215  br=far  ptr=0  look=25  α_W=0.49  α_G=1.26  dead=None  v=0.40  ω=1.50
# [DBG] d=2.219  br=far  ptr=0  look=25  α_W=0.52  α_G=1.20  dead=None  v=0.40  ω=1.59
# [DBG] d=2.223  br=far  ptr=0  look=25  α_W=0.56  α_G=1.15  dead=None  v=0.40  ω=1.70
# [DBG] d=2.227  br=far  ptr=0  look=25  α_W=0.60  α_G=1.09  dead=None  v=0.40  ω=1.82
# [DBG] d=2.231  br=far  ptr=0  look=25  α_W=0.67  α_G=1.02  dead=None  v=0.40  ω=1.99
# [DBG] d=2.233  br=far  ptr=0  look=25  α_W=0.72  α_G=0.95  dead=None  v=0.40  ω=2.12
# [DBG] d=2.232  br=far  ptr=0  look=25  α_W=0.78  α_G=0.85  dead=None  v=0.40  ω=2.25
# [DBG] d=2.231  br=far  ptr=0  look=25  α_W=0.84  α_G=0.73  dead=None  v=0.40  ω=2.39
# [DBG] d=2.226  br=far  ptr=0  look=25  α_W=0.93  α_G=0.61  dead=None  v=0.40  ω=2.56
# [DBG] d=2.217  br=far  ptr=0  look=25  α_W=0.99  α_G=0.51  dead=None  v=0.40  ω=2.67
# [DBG] d=2.204  br=far  ptr=0  look=25  α_W=1.04  α_G=0.37  dead=None  v=0.40  ω=2.76
# [DBG] d=2.188  br=far  ptr=0  look=25  α_W=1.13  α_G=0.22  dead=None  v=0.40  ω=2.90
# [DBG] d=2.168  br=far  ptr=0  look=25  α_W=1.18  α_G=0.05  dead=None  v=0.40  ω=2.95
# [DBG] d=2.146  br=far  ptr=0  look=25  α_W=1.20  α_G=-0.13  dead=None  v=0.40  ω=2.99
# [DBG] d=2.121  br=far  ptr=0  look=25  α_W=1.22  α_G=-0.31  dead=None  v=0.40  ω=3.01
# [DBG] d=2.095  br=far  ptr=0  look=25  α_W=1.24  α_G=-0.49  dead=None  v=0.40  ω=3.03
# [DBG] d=2.068  br=far  ptr=0  look=25  α_W=1.26  α_G=-0.67  dead=None  v=0.40  ω=3.05
# [DBG] d=2.040  br=far  ptr=0  look=25  α_W=1.28  α_G=-0.86  dead=None  v=0.40  ω=3.07
# [DBG] d=2.021  br=far  ptr=0  look=25  α_W=1.29  α_G=-1.02  dead=None  v=0.40  ω=3.08
# [DBG] d=2.001  br=far  ptr=0  look=25  α_W=1.30  α_G=-1.20  dead=None  v=0.40  ω=3.08
# [DBG] d=1.979  br=far  ptr=0  look=25  α_W=1.30  α_G=-1.38  dead=None  v=0.40  ω=3.08
# [DBG] d=1.966  br=far  ptr=0  look=25  α_W=1.25  α_G=-1.57  dead=None  v=0.40  ω=3.04
# [DBG] d=1.951  br=far  ptr=0  look=25  α_W=1.25  α_G=-1.76  dead=None  v=0.40  ω=3.04
# [DBG] d=1.946  br=far  ptr=0  look=25  α_W=1.23  α_G=-1.95  dead=None  v=0.40  ω=3.02
# [DBG] d=1.945  br=far  ptr=0  look=25  α_W=1.21  α_G=-2.15  dead=None  v=0.40  ω=2.99
# [DBG] d=1.949  br=far  ptr=0  look=25  α_W=1.19  α_G=-2.33  dead=None  v=0.40  ω=2.97
# [DBG] d=1.958  br=far  ptr=0  look=25  α_W=1.17  α_G=-2.49  dead=None  v=0.40  ω=2.94
# [DBG] d=1.970  br=far  ptr=0  look=25  α_W=1.14  α_G=-2.68  dead=None  v=0.40  ω=2.90
# [DBG] d=1.985  br=far  ptr=0  look=25  α_W=1.11  α_G=-2.84  dead=None  v=0.40  ω=2.87
# [DBG] d=2.003  br=far  ptr=0  look=25  α_W=1.09  α_G=-3.00  dead=None  v=0.40  ω=2.84
# [DBG] d=2.025  br=far  ptr=0  look=25  α_W=1.06  α_G=3.11  dead=None  v=0.40  ω=2.79
# [DBG] d=2.047  br=far  ptr=0  look=25  α_W=1.03  α_G=2.95  dead=None  v=0.40  ω=2.74
# [DBG] d=2.071  br=far  ptr=0  look=25  α_W=1.01  α_G=2.80  dead=None  v=0.40  ω=2.71
# [DBG] d=2.096  br=far  ptr=0  look=25  α_W=0.99  α_G=2.64  dead=None  v=0.40  ω=2.68
# [DBG] d=2.121  br=far  ptr=0  look=25  α_W=0.98  α_G=2.50  dead=None  v=0.40  ω=2.65
# [DBG] d=2.146  br=far  ptr=0  look=25  α_W=0.96  α_G=2.35  dead=None  v=0.40  ω=2.63
# [DBG] d=2.169  br=far  ptr=0  look=25  α_W=0.95  α_G=2.21  dead=None  v=0.40  ω=2.60
# [DBG] d=2.187  br=far  ptr=0  look=25  α_W=0.93  α_G=2.09  dead=None  v=0.40  ω=2.56
# [DBG] d=2.210  br=far  ptr=0  look=25  α_W=0.93  α_G=1.95  dead=None  v=0.40  ω=2.56
# [DBG] d=2.228  br=far  ptr=0  look=25  α_W=0.93  α_G=1.83  dead=None  v=0.40  ω=2.56
# [DBG] d=2.246  br=far  ptr=0  look=25  α_W=0.91  α_G=1.69  dead=None  v=0.40  ω=2.52
# [DBG] d=2.260  br=far  ptr=0  look=25  α_W=0.91  α_G=1.58  dead=None  v=0.40  ω=2.52
# [DBG] d=2.275  br=far  ptr=0  look=25  α_W=0.90  α_G=1.45  dead=None  v=0.40  ω=2.52
# [DBG] d=2.286  br=far  ptr=0  look=25  α_W=0.91  α_G=1.35  dead=None  v=0.40  ω=2.53
# [DBG] d=2.289  br=far  ptr=0  look=25  α_W=0.89  α_G=1.22  dead=None  v=0.40  ω=2.49
# [DBG] d=2.293  br=far  ptr=0  look=25  α_W=0.88  α_G=1.10  dead=None  v=0.40  ω=2.47
# [DBG] d=2.297  br=far  ptr=0  look=25  α_W=0.87  α_G=0.97  dead=None  v=0.40  ω=2.44
# [DBG] d=2.296  br=far  ptr=0  look=25  α_W=0.86  α_G=0.84  dead=None  v=0.40  ω=2.43
# [DBG] d=2.293  br=far  ptr=0  look=25  α_W=0.86  α_G=0.72  dead=None  v=0.40  ω=2.42
# [DBG] d=2.287  br=far  ptr=0  look=25  α_W=0.87  α_G=0.60  dead=None  v=0.40  ω=2.44
# [DBG] d=2.280  br=far  ptr=0  look=25  α_W=0.87  α_G=0.50  dead=None  v=0.40  ω=2.44
# [DBG] d=2.269  br=far  ptr=0  look=25  α_W=0.86  α_G=0.38  dead=None  v=0.40  ω=2.42
# [DBG] d=2.259  br=far  ptr=0  look=25  α_W=0.87  α_G=0.27  dead=None  v=0.40  ω=2.44
# [DBG] d=2.243  br=far  ptr=0  look=25  α_W=0.86  α_G=0.14  dead=None  v=0.40  ω=2.42
# [DBG] d=2.230  br=far  ptr=0  look=25  α_W=0.86  α_G=0.04  dead=None  v=0.40  ω=2.43
# [DBG] d=2.210  br=far  ptr=0  look=25  α_W=0.86  α_G=-0.10  dead=None  v=0.40  ω=2.43
# [DBG] d=2.192  br=far  ptr=0  look=25  α_W=0.88  α_G=-0.21  dead=None  v=0.40  ω=2.46
# [DBG] d=2.172  br=far  ptr=0  look=25  α_W=0.88  α_G=-0.33  dead=None  v=0.40  ω=2.46
# [DBG] d=2.151  br=far  ptr=0  look=25  α_W=0.90  α_G=-0.44  dead=None  v=0.40  ω=2.50
# [DBG] d=2.132  br=far  ptr=0  look=25  α_W=0.89  α_G=-0.57  dead=None  v=0.40  ω=2.48
# [DBG] d=2.111  br=far  ptr=0  look=25  α_W=0.89  α_G=-0.71  dead=None  v=0.40  ω=2.48
# [DBG] d=2.088  br=far  ptr=0  look=25  α_W=0.90  α_G=-0.84  dead=None  v=0.40  ω=2.50
# [DBG] d=2.068  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.98  dead=None  v=0.40  ω=2.53
# [DBG] d=2.050  br=far  ptr=0  look=25  α_W=0.92  α_G=-1.10  dead=None  v=0.40  ω=2.55
# [DBG] d=2.029  br=far  ptr=0  look=25  α_W=0.92  α_G=-1.26  dead=None  v=0.40  ω=2.56
# [DBG] d=2.009  br=far  ptr=0  look=25  α_W=0.93  α_G=-1.42  dead=None  v=0.40  ω=2.56
# [DBG] d=1.990  br=far  ptr=0  look=25  α_W=0.96  α_G=-1.56  dead=None  v=0.40  ω=2.62
# [DBG] d=1.976  br=far  ptr=0  look=25  α_W=0.95  α_G=-1.72  dead=None  v=0.40  ω=2.61
# [DBG] d=1.965  br=far  ptr=0  look=25  α_W=0.95  α_G=-1.89  dead=None  v=0.40  ω=2.60
# [DBG] d=1.959  br=far  ptr=0  look=25  α_W=0.96  α_G=-2.04  dead=None  v=0.40  ω=2.63
# [DBG] d=1.956  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.18  dead=None  v=0.40  ω=2.66
# [DBG] d=1.962  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.33  dead=None  v=0.40  ω=2.64
# [DBG] d=1.967  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.50  dead=None  v=0.40  ω=2.64
# [DBG] d=1.975  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.65  dead=None  v=0.40  ω=2.64
# [DBG] d=1.987  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.81  dead=None  v=0.40  ω=2.64
# [DBG] d=2.001  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.97  dead=None  v=0.40  ω=2.63
# [DBG] d=2.018  br=far  ptr=0  look=25  α_W=0.96  α_G=-3.14  dead=None  v=0.40  ω=2.61
# [DBG] d=2.038  br=far  ptr=0  look=25  α_W=0.96  α_G=3.00  dead=None  v=0.40  ω=2.62
# [DBG] d=2.059  br=far  ptr=0  look=25  α_W=0.97  α_G=2.86  dead=None  v=0.40  ω=2.64
# [DBG] d=2.081  br=far  ptr=0  look=25  α_W=0.95  α_G=2.72  dead=None  v=0.40  ω=2.61
# [DBG] d=2.105  br=far  ptr=0  look=25  α_W=0.95  α_G=2.57  dead=None  v=0.40  ω=2.60
# [DBG] d=2.126  br=far  ptr=0  look=25  α_W=0.95  α_G=2.44  dead=None  v=0.40  ω=2.59
# [DBG] d=2.146  br=far  ptr=0  look=25  α_W=0.94  α_G=2.32  dead=None  v=0.40  ω=2.59
# [DBG] d=2.165  br=far  ptr=0  look=25  α_W=0.94  α_G=2.19  dead=None  v=0.40  ω=2.58
# [DBG] d=2.188  br=far  ptr=0  look=25  α_W=0.95  α_G=2.05  dead=None  v=0.40  ω=2.61
# [DBG] d=2.207  br=far  ptr=0  look=25  α_W=0.97  α_G=1.94  dead=None  v=0.40  ω=2.63
# [DBG] d=2.218  br=far  ptr=0  look=25  α_W=0.94  α_G=1.80  dead=None  v=0.40  ω=2.59
# [DBG] d=2.237  br=far  ptr=0  look=25  α_W=0.94  α_G=1.65  dead=None  v=0.40  ω=2.59
# [DBG] d=2.254  br=far  ptr=0  look=25  α_W=0.97  α_G=1.52  dead=None  v=0.40  ω=2.63
# [DBG] d=2.270  br=far  ptr=0  look=25  α_W=0.96  α_G=1.37  dead=None  v=0.40  ω=2.62
# [DBG] d=2.275  br=far  ptr=0  look=25  α_W=0.95  α_G=1.25  dead=None  v=0.40  ω=2.61
# [DBG] d=2.277  br=far  ptr=0  look=25  α_W=0.95  α_G=1.13  dead=None  v=0.40  ω=2.60
# [DBG] d=2.277  br=far  ptr=0  look=25  α_W=0.95  α_G=1.01  dead=None  v=0.40  ω=2.60
# [DBG] d=2.275  br=far  ptr=0  look=25  α_W=0.95  α_G=0.90  dead=None  v=0.40  ω=2.60
# [DBG] d=2.270  br=far  ptr=0  look=25  α_W=0.95  α_G=0.78  dead=None  v=0.40  ω=2.60
# [DBG] d=2.264  br=far  ptr=0  look=25  α_W=0.96  α_G=0.64  dead=None  v=0.40  ω=2.62
# [DBG] d=2.256  br=far  ptr=0  look=25  α_W=0.97  α_G=0.50  dead=None  v=0.40  ω=2.63
# [DBG] d=2.245  br=far  ptr=0  look=25  α_W=0.97  α_G=0.36  dead=None  v=0.40  ω=2.64
# [DBG] d=2.230  br=far  ptr=0  look=25  α_W=0.98  α_G=0.21  dead=None  v=0.40  ω=2.66
# [DBG] d=2.214  br=far  ptr=0  look=25  α_W=1.00  α_G=0.09  dead=None  v=0.40  ω=2.69
# [DBG] d=2.193  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.07  dead=None  v=0.40  ω=2.70
# [DBG] d=2.174  br=far  ptr=0  look=25  α_W=1.02  α_G=-0.19  dead=None  v=0.40  ω=2.72
# [DBG] d=2.154  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.34  dead=None  v=0.40  ω=2.67
# [DBG] d=2.129  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.48  dead=None  v=0.40  ω=2.68
# [DBG] d=2.104  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.64  dead=None  v=0.40  ω=2.69
# [DBG] d=2.079  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.79  dead=None  v=0.40  ω=2.69
# [DBG] d=2.057  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.94  dead=None  v=0.40  ω=2.70
# [DBG] d=2.036  br=far  ptr=0  look=25  α_W=1.01  α_G=-1.07  dead=None  v=0.40  ω=2.71
# [DBG] d=2.023  br=far  ptr=0  look=25  α_W=1.00  α_G=-1.21  dead=None  v=0.40  ω=2.69
# [DBG] d=2.003  br=far  ptr=0  look=25  α_W=0.99  α_G=-1.38  dead=None  v=0.40  ω=2.68
# [DBG] d=1.984  br=far  ptr=0  look=25  α_W=1.01  α_G=-1.54  dead=None  v=0.40  ω=2.71
# [DBG] d=1.972  br=far  ptr=0  look=25  α_W=1.00  α_G=-1.71  dead=None  v=0.40  ω=2.70
# [DBG] d=1.964  br=far  ptr=0  look=25  α_W=1.00  α_G=-1.88  dead=None  v=0.40  ω=2.69
# [DBG] d=1.961  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.04  dead=None  v=0.40  ω=2.68
# [DBG] d=1.963  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.21  dead=None  v=0.40  ω=2.68
# [DBG] d=1.968  br=far  ptr=0  look=25  α_W=1.00  α_G=-2.37  dead=None  v=0.40  ω=2.70
# [DBG] d=1.978  br=far  ptr=0  look=25  α_W=1.02  α_G=-2.53  dead=None  v=0.40  ω=2.72
# [DBG] d=1.991  br=far  ptr=0  look=25  α_W=1.03  α_G=-2.69  dead=None  v=0.40  ω=2.74
# [DBG] d=2.007  br=far  ptr=0  look=25  α_W=1.04  α_G=-2.86  dead=None  v=0.40  ω=2.76
# [DBG] d=2.023  br=far  ptr=0  look=25  α_W=1.04  α_G=-3.03  dead=None  v=0.40  ω=2.76
# [DBG] d=2.042  br=far  ptr=0  look=25  α_W=1.03  α_G=3.07  dead=None  v=0.40  ω=2.74
# [DBG] d=2.062  br=far  ptr=0  look=25  α_W=1.01  α_G=2.90  dead=None  v=0.40  ω=2.71
# [DBG] d=2.086  br=far  ptr=0  look=25  α_W=1.00  α_G=2.74  dead=None  v=0.40  ω=2.70
# [DBG] d=2.111  br=far  ptr=0  look=25  α_W=1.00  α_G=2.59  dead=None  v=0.40  ω=2.70
# [DBG] d=2.135  br=far  ptr=0  look=25  α_W=1.00  α_G=2.44  dead=None  v=0.40  ω=2.69
# [DBG] d=2.159  br=far  ptr=0  look=25  α_W=1.00  α_G=2.29  dead=None  v=0.40  ω=2.69
# [DBG] d=2.181  br=far  ptr=0  look=25  α_W=1.00  α_G=2.14  dead=None  v=0.40  ω=2.69
# [DBG] d=2.204  br=far  ptr=0  look=25  α_W=1.00  α_G=1.99  dead=None  v=0.40  ω=2.70
# [DBG] d=2.223  br=far  ptr=0  look=25  α_W=0.99  α_G=1.85  dead=None  v=0.40  ω=2.68
# [DBG] d=2.242  br=far  ptr=0  look=25  α_W=0.98  α_G=1.70  dead=None  v=0.40  ω=2.65
# [DBG] d=2.258  br=far  ptr=0  look=25  α_W=0.96  α_G=1.55  dead=None  v=0.40  ω=2.62
# [DBG] d=2.273  br=far  ptr=0  look=25  α_W=0.97  α_G=1.41  dead=None  v=0.40  ω=2.64
# [DBG] d=2.285  br=far  ptr=0  look=25  α_W=0.95  α_G=1.26  dead=None  v=0.40  ω=2.61
# [DBG] d=2.290  br=far  ptr=0  look=25  α_W=0.95  α_G=1.13  dead=None  v=0.40  ω=2.60
# [DBG] d=2.292  br=far  ptr=0  look=25  α_W=0.94  α_G=1.00  dead=None  v=0.40  ω=2.59
# [DBG] d=2.290  br=far  ptr=0  look=25  α_W=0.94  α_G=0.87  dead=None  v=0.40  ω=2.59
# [DBG] d=2.285  br=far  ptr=0  look=25  α_W=0.94  α_G=0.73  dead=None  v=0.40  ω=2.59
# [DBG] d=2.277  br=far  ptr=0  look=25  α_W=0.94  α_G=0.60  dead=None  v=0.40  ω=2.59
# [DBG] d=2.268  br=far  ptr=0  look=25  α_W=0.94  α_G=0.46  dead=None  v=0.40  ω=2.58
# [DBG] d=2.257  br=far  ptr=0  look=25  α_W=0.93  α_G=0.33  dead=None  v=0.40  ω=2.56
# [DBG] d=2.244  br=far  ptr=0  look=25  α_W=0.93  α_G=0.20  dead=None  v=0.40  ω=2.56
# [DBG] d=2.229  br=far  ptr=0  look=25  α_W=0.93  α_G=0.08  dead=None  v=0.40  ω=2.57
# [DBG] d=2.213  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.06  dead=None  v=0.40  ω=2.52
# [DBG] d=2.192  br=far  ptr=0  look=25  α_W=0.92  α_G=-0.18  dead=None  v=0.40  ω=2.55
# [DBG] d=2.172  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.31  dead=None  v=0.40  ω=2.53
# [DBG] d=2.152  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.42  dead=None  v=0.40  ω=2.53
# [DBG] d=2.133  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.54  dead=None  v=0.40  ω=2.53
# [DBG] d=2.114  br=far  ptr=0  look=25  α_W=0.91  α_G=-0.66  dead=None  v=0.40  ω=2.53
# [DBG] d=2.090  br=far  ptr=0  look=25  α_W=0.93  α_G=-0.80  dead=None  v=0.40  ω=2.56
# [DBG] d=2.068  br=far  ptr=0  look=25  α_W=0.93  α_G=-0.95  dead=None  v=0.40  ω=2.56
# [DBG] d=2.046  br=far  ptr=0  look=25  α_W=0.94  α_G=-1.10  dead=None  v=0.40  ω=2.58
# [DBG] d=2.025  br=far  ptr=0  look=25  α_W=0.94  α_G=-1.26  dead=None  v=0.40  ω=2.58
# [DBG] d=2.005  br=far  ptr=0  look=25  α_W=0.96  α_G=-1.40  dead=None  v=0.40  ω=2.63
# [DBG] d=1.985  br=far  ptr=0  look=25  α_W=0.96  α_G=-1.57  dead=None  v=0.40  ω=2.62
# [DBG] d=1.971  br=far  ptr=0  look=25  α_W=0.98  α_G=-1.72  dead=None  v=0.40  ω=2.66
# [DBG] d=1.960  br=far  ptr=0  look=25  α_W=1.00  α_G=-1.87  dead=None  v=0.40  ω=2.69
# [DBG] d=1.958  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.03  dead=None  v=0.40  ω=2.67
# [DBG] d=1.959  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.19  dead=None  v=0.40  ω=2.66
# [DBG] d=1.965  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.34  dead=None  v=0.40  ω=2.66
# [DBG] d=1.975  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.49  dead=None  v=0.40  ω=2.67
# [DBG] d=1.984  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.66  dead=None  v=0.40  ω=2.68
# [DBG] d=1.996  br=far  ptr=0  look=25  α_W=1.00  α_G=-2.82  dead=None  v=0.40  ω=2.68
# [DBG] d=2.013  br=far  ptr=0  look=25  α_W=1.02  α_G=-2.98  dead=None  v=0.40  ω=2.73
# [DBG] d=2.029  br=far  ptr=0  look=25  α_W=1.00  α_G=-3.14  dead=None  v=0.40  ω=2.70
# [DBG] d=2.053  br=far  ptr=0  look=25  α_W=1.02  α_G=2.98  dead=None  v=0.40  ω=2.73
# [DBG] d=2.077  br=far  ptr=0  look=25  α_W=1.04  α_G=2.83  dead=None  v=0.40  ω=2.76
# [DBG] d=2.098  br=far  ptr=0  look=25  α_W=1.02  α_G=2.69  dead=None  v=0.40  ω=2.72
# [DBG] d=2.116  br=far  ptr=0  look=25  α_W=1.01  α_G=2.56  dead=None  v=0.40  ω=2.70
# [DBG] d=2.134  br=far  ptr=0  look=25  α_W=1.00  α_G=2.44  dead=None  v=0.40  ω=2.69
# [DBG] d=2.153  br=far  ptr=0  look=25  α_W=0.99  α_G=2.31  dead=None  v=0.40  ω=2.68
# [DBG] d=2.177  br=far  ptr=0  look=25  α_W=1.01  α_G=2.17  dead=None  v=0.40  ω=2.71
# [DBG] d=2.197  br=far  ptr=0  look=25  α_W=1.03  α_G=2.04  dead=None  v=0.40  ω=2.74
# [DBG] d=2.213  br=far  ptr=0  look=25  α_W=1.03  α_G=1.90  dead=None  v=0.40  ω=2.75
# [DBG] d=2.231  br=far  ptr=0  look=25  α_W=1.05  α_G=1.77  dead=None  v=0.40  ω=2.78
# [DBG] d=2.245  br=far  ptr=0  look=25  α_W=1.06  α_G=1.62  dead=None  v=0.40  ω=2.79
# [DBG] d=2.256  br=far  ptr=0  look=25  α_W=1.07  α_G=1.47  dead=None  v=0.40  ω=2.81
# [DBG] d=2.264  br=far  ptr=0  look=25  α_W=1.08  α_G=1.33  dead=None  v=0.40  ω=2.82
# [DBG] d=2.268  br=far  ptr=0  look=25  α_W=1.09  α_G=1.18  dead=None  v=0.40  ω=2.84
# [DBG] d=2.271  br=far  ptr=0  look=25  α_W=1.11  α_G=1.03  dead=None  v=0.40  ω=2.86
# [DBG] d=2.266  br=far  ptr=0  look=25  α_W=1.12  α_G=0.88  dead=None  v=0.40  ω=2.88
# [DBG] d=2.261  br=far  ptr=0  look=25  α_W=1.13  α_G=0.73  dead=None  v=0.40  ω=2.89
# [DBG] d=2.250  br=far  ptr=0  look=25  α_W=1.13  α_G=0.58  dead=None  v=0.40  ω=2.90
# [DBG] d=2.238  br=far  ptr=0  look=25  α_W=1.14  α_G=0.45  dead=None  v=0.40  ω=2.90
# [DBG] d=2.220  br=far  ptr=0  look=25  α_W=1.14  α_G=0.29  dead=None  v=0.40  ω=2.91
# [DBG] d=2.201  br=far  ptr=0  look=25  α_W=1.14  α_G=0.13  dead=None  v=0.40  ω=2.91
# [DBG] d=2.179  br=far  ptr=0  look=25  α_W=1.13  α_G=-0.03  dead=None  v=0.40  ω=2.90
# [DBG] d=2.155  br=far  ptr=0  look=25  α_W=1.13  α_G=-0.19  dead=None  v=0.40  ω=2.90
# [DBG] d=2.129  br=far  ptr=0  look=25  α_W=1.13  α_G=-0.35  dead=None  v=0.40  ω=2.89
# [DBG] d=2.102  br=far  ptr=0  look=25  α_W=1.13  α_G=-0.52  dead=None  v=0.40  ω=2.89
# [DBG] d=2.075  br=far  ptr=0  look=25  α_W=1.12  α_G=-0.68  dead=None  v=0.40  ω=2.88
# [DBG] d=2.049  br=far  ptr=0  look=25  α_W=1.11  α_G=-0.85  dead=None  v=0.40  ω=2.87
# [DBG] d=2.029  br=far  ptr=0  look=25  α_W=1.10  α_G=-1.01  dead=None  v=0.40  ω=2.85
# [DBG] d=2.007  br=far  ptr=0  look=25  α_W=1.10  α_G=-1.17  dead=None  v=0.40  ω=2.85
# [DBG] d=1.988  br=far  ptr=0  look=25  α_W=1.09  α_G=-1.34  dead=None  v=0.40  ω=2.83
# [DBG] d=1.971  br=far  ptr=0  look=25  α_W=1.07  α_G=-1.51  dead=None  v=0.40  ω=2.81
# [DBG] d=1.960  br=far  ptr=0  look=25  α_W=1.05  α_G=-1.67  dead=None  v=0.40  ω=2.78
# [DBG] d=1.953  br=far  ptr=0  look=25  α_W=1.03  α_G=-1.81  dead=None  v=0.40  ω=2.75
# [DBG] d=1.949  br=far  ptr=0  look=25  α_W=1.02  α_G=-1.96  dead=None  v=0.40  ω=2.72
# [DBG] d=1.949  br=far  ptr=0  look=25  α_W=1.01  α_G=-2.10  dead=None  v=0.40  ω=2.71
# [DBG] d=1.950  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.25  dead=None  v=0.40  ω=2.68
# [DBG] d=1.953  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.41  dead=None  v=0.40  ω=2.67
# [DBG] d=1.962  br=far  ptr=0  look=25  α_W=1.00  α_G=-2.56  dead=None  v=0.40  ω=2.69
# [DBG] d=1.976  br=far  ptr=0  look=25  α_W=0.99  α_G=-2.71  dead=None  v=0.40  ω=2.68
# [DBG] d=1.989  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.88  dead=None  v=0.40  ω=2.66
# [DBG] d=2.005  br=far  ptr=0  look=25  α_W=0.97  α_G=-3.05  dead=None  v=0.40  ω=2.64
# [DBG] d=2.021  br=far  ptr=0  look=25  α_W=0.95  α_G=3.10  dead=None  v=0.40  ω=2.60
# [DBG] d=2.039  br=far  ptr=0  look=25  α_W=0.94  α_G=2.96  dead=None  v=0.40  ω=2.58
# [DBG] d=2.057  br=far  ptr=0  look=25  α_W=0.92  α_G=2.83  dead=None  v=0.40  ω=2.55
# [DBG] d=2.076  br=far  ptr=0  look=25  α_W=0.91  α_G=2.71  dead=None  v=0.40  ω=2.54
# [DBG] d=2.095  br=far  ptr=0  look=25  α_W=0.91  α_G=2.59  dead=None  v=0.40  ω=2.52
# [DBG] d=2.114  br=far  ptr=0  look=25  α_W=0.90  α_G=2.47  dead=None  v=0.40  ω=2.51
# [DBG] d=2.133  br=far  ptr=0  look=25  α_W=0.90  α_G=2.35  dead=None  v=0.40  ω=2.50
# [DBG] d=2.157  br=far  ptr=0  look=25  α_W=0.91  α_G=2.21  dead=None  v=0.40  ω=2.53
# [DBG] d=2.172  br=far  ptr=0  look=25  α_W=0.92  α_G=2.11  dead=None  v=0.40  ω=2.54
# [DBG] d=2.193  br=far  ptr=0  look=25  α_W=0.94  α_G=1.99  dead=None  v=0.40  ω=2.58
# [DBG] d=2.211  br=far  ptr=0  look=25  α_W=0.93  α_G=1.85  dead=None  v=0.40  ω=2.57
# [DBG] d=2.230  br=far  ptr=0  look=25  α_W=0.93  α_G=1.70  dead=None  v=0.40  ω=2.57
# [DBG] d=2.248  br=far  ptr=0  look=25  α_W=0.93  α_G=1.56  dead=None  v=0.40  ω=2.56
# [DBG] d=2.264  br=far  ptr=0  look=25  α_W=0.92  α_G=1.41  dead=None  v=0.40  ω=2.55
# [DBG] d=2.276  br=far  ptr=0  look=25  α_W=0.94  α_G=1.28  dead=None  v=0.40  ω=2.59
# [DBG] d=2.284  br=far  ptr=0  look=25  α_W=0.96  α_G=1.16  dead=None  v=0.40  ω=2.63
# [DBG] d=2.284  br=far  ptr=0  look=25  α_W=0.95  α_G=1.02  dead=None  v=0.40  ω=2.61
# [DBG] d=2.281  br=far  ptr=0  look=25  α_W=0.95  α_G=0.89  dead=None  v=0.40  ω=2.60
# [DBG] d=2.274  br=far  ptr=0  look=25  α_W=0.95  α_G=0.77  dead=None  v=0.40  ω=2.61
# [DBG] d=2.265  br=far  ptr=0  look=25  α_W=0.96  α_G=0.64  dead=None  v=0.40  ω=2.62
# [DBG] d=2.256  br=far  ptr=0  look=25  α_W=0.96  α_G=0.50  dead=None  v=0.40  ω=2.63
# [DBG] d=2.245  br=far  ptr=0  look=25  α_W=0.97  α_G=0.36  dead=None  v=0.40  ω=2.63
# [DBG] d=2.230  br=far  ptr=0  look=25  α_W=0.99  α_G=0.22  dead=None  v=0.40  ω=2.67
# [DBG] d=2.214  br=far  ptr=0  look=25  α_W=0.98  α_G=0.07  dead=None  v=0.40  ω=2.66
# [DBG] d=2.196  br=far  ptr=0  look=25  α_W=0.98  α_G=-0.07  dead=None  v=0.40  ω=2.66
# [DBG] d=2.173  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.21  dead=None  v=0.40  ω=2.69
# [DBG] d=2.150  br=far  ptr=0  look=25  α_W=1.00  α_G=-0.35  dead=None  v=0.40  ω=2.69
# [DBG] d=2.126  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.50  dead=None  v=0.40  ω=2.68
# [DBG] d=2.103  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.64  dead=None  v=0.40  ω=2.68
# [DBG] d=2.079  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.79  dead=None  v=0.40  ω=2.68
# [DBG] d=2.055  br=far  ptr=0  look=25  α_W=0.99  α_G=-0.95  dead=None  v=0.40  ω=2.68
# [DBG] d=2.034  br=far  ptr=0  look=25  α_W=0.98  α_G=-1.11  dead=None  v=0.40  ω=2.66
# [DBG] d=2.015  br=far  ptr=0  look=25  α_W=0.97  α_G=-1.26  dead=None  v=0.40  ω=2.63
# [DBG] d=1.995  br=far  ptr=0  look=25  α_W=0.98  α_G=-1.41  dead=None  v=0.40  ω=2.66
# [DBG] d=1.981  br=far  ptr=0  look=25  α_W=0.97  α_G=-1.57  dead=None  v=0.40  ω=2.63
# [DBG] d=1.969  br=far  ptr=0  look=25  α_W=0.95  α_G=-1.73  dead=None  v=0.40  ω=2.61
# [DBG] d=1.961  br=far  ptr=0  look=25  α_W=0.94  α_G=-1.90  dead=None  v=0.40  ω=2.58
# [DBG] d=1.958  br=far  ptr=0  look=25  α_W=0.93  α_G=-2.05  dead=None  v=0.40  ω=2.56
# [DBG] d=1.960  br=far  ptr=0  look=25  α_W=0.93  α_G=-2.20  dead=None  v=0.40  ω=2.56
# [DBG] d=1.965  br=far  ptr=0  look=25  α_W=0.93  α_G=-2.35  dead=None  v=0.40  ω=2.57
# [DBG] d=1.974  br=far  ptr=0  look=25  α_W=0.95  α_G=-2.50  dead=None  v=0.40  ω=2.59
# [DBG] d=1.983  br=far  ptr=0  look=25  α_W=0.95  α_G=-2.66  dead=None  v=0.40  ω=2.61
# [DBG] d=1.994  br=far  ptr=0  look=25  α_W=0.96  α_G=-2.82  dead=None  v=0.40  ω=2.62
# [DBG] d=2.007  br=far  ptr=0  look=25  α_W=0.95  α_G=-2.96  dead=None  v=0.40  ω=2.61
# [DBG] d=2.026  br=far  ptr=0  look=25  α_W=0.98  α_G=-3.12  dead=None  v=0.40  ω=2.66
# [DBG] d=2.045  br=far  ptr=0  look=25  α_W=1.00  α_G=3.03  dead=None  v=0.40  ω=2.69
# [DBG] d=2.065  br=far  ptr=0  look=25  α_W=0.97  α_G=2.86  dead=None  v=0.40  ω=2.64
# [DBG] d=2.088  br=far  ptr=0  look=25  α_W=1.00  α_G=2.73  dead=None  v=0.40  ω=2.68
# [DBG] d=2.109  br=far  ptr=0  look=25  α_W=0.98  α_G=2.59  dead=None  v=0.40  ω=2.66
# [DBG] d=2.128  br=far  ptr=0  look=25  α_W=0.98  α_G=2.46  dead=None  v=0.40  ω=2.66
# [DBG] d=2.152  br=far  ptr=0  look=25  α_W=0.99  α_G=2.32  dead=None  v=0.40  ω=2.67
# [DBG] d=2.170  br=far  ptr=0  look=25  α_W=1.00  α_G=2.19  dead=None  v=0.40  ω=2.69
# [DBG] d=2.191  br=far  ptr=0  look=25  α_W=1.02  α_G=2.06  dead=None  v=0.40  ω=2.73
# [DBG] d=2.211  br=far  ptr=0  look=25  α_W=1.04  α_G=1.93  dead=None  v=0.40  ω=2.76
# [DBG] d=2.228  br=far  ptr=0  look=25  α_W=1.05  α_G=1.78  dead=None  v=0.40  ω=2.77
# [DBG] d=2.243  br=far  ptr=0  look=25  α_W=1.06  α_G=1.63  dead=None  v=0.40  ω=2.79
# [DBG] d=2.256  br=far  ptr=0  look=25  α_W=1.06  α_G=1.47  dead=None  v=0.40  ω=2.79
# [DBG] d=2.265  br=far  ptr=0  look=25  α_W=1.06  α_G=1.31  dead=None  v=0.40  ω=2.79
# [DBG] d=2.271  br=far  ptr=0  look=25  α_W=1.06  α_G=1.16  dead=None  v=0.40  ω=2.79
# [DBG] d=2.271  br=far  ptr=0  look=25  α_W=1.06  α_G=1.01  dead=None  v=0.40  ω=2.79
# [DBG] d=2.266  br=far  ptr=0  look=25  α_W=1.07  α_G=0.86  dead=None  v=0.40  ω=2.81
# [DBG] d=2.257  br=far  ptr=0  look=25  α_W=1.09  α_G=0.71  dead=None  v=0.40  ω=2.83
# [DBG] d=2.246  br=far  ptr=0  look=25  α_W=1.10  α_G=0.56  dead=None  v=0.40  ω=2.86
# [DBG] d=2.233  br=far  ptr=0  look=25  α_W=1.11  α_G=0.40  dead=None  v=0.40  ω=2.87
# [DBG] d=2.219  br=far  ptr=0  look=25  α_W=1.10  α_G=0.25  dead=None  v=0.40  ω=2.85
# [DBG] d=2.201  br=far  ptr=0  look=25  α_W=1.10  α_G=0.08  dead=None  v=0.40  ω=2.85
# [DBG] d=2.181  br=far  ptr=0  look=25  α_W=1.11  α_G=-0.05  dead=None  v=0.40  ω=2.87
# [DBG] d=2.159  br=far  ptr=0  look=25  α_W=1.07  α_G=-0.23  dead=None  v=0.40  ω=2.81
# [DBG] d=2.135  br=far  ptr=0  look=25  α_W=1.06  α_G=-0.38  dead=None  v=0.40  ω=2.80
# [DBG] d=2.109  br=far  ptr=0  look=25  α_W=1.06  α_G=-0.54  dead=None  v=0.40  ω=2.79
# [DBG] d=2.083  br=far  ptr=0  look=25  α_W=1.05  α_G=-0.70  dead=None  v=0.40  ω=2.78
# [DBG] d=2.058  br=far  ptr=0  look=25  α_W=1.05  α_G=-0.87  dead=None  v=0.40  ω=2.77
# [DBG] d=2.034  br=far  ptr=0  look=25  α_W=1.03  α_G=-1.03  dead=None  v=0.40  ω=2.75
# [DBG] d=2.014  br=far  ptr=0  look=25  α_W=1.02  α_G=-1.18  dead=None  v=0.40  ω=2.73
# [DBG] d=1.998  br=far  ptr=0  look=25  α_W=1.01  α_G=-1.33  dead=None  v=0.40  ω=2.70
# [DBG] d=1.985  br=far  ptr=0  look=25  α_W=0.99  α_G=-1.47  dead=None  v=0.40  ω=2.68
# [DBG] d=1.975  br=far  ptr=0  look=25  α_W=0.98  α_G=-1.61  dead=None  v=0.40  ω=2.66
# [DBG] d=1.967  br=far  ptr=0  look=25  α_W=0.97  α_G=-1.75  dead=None  v=0.40  ω=2.64
# [DBG] d=1.963  br=far  ptr=0  look=25  α_W=0.97  α_G=-1.88  dead=None  v=0.40  ω=2.63
# [DBG] d=1.961  br=far  ptr=0  look=25  α_W=0.96  α_G=-2.01  dead=None  v=0.40  ω=2.63
# [DBG] d=1.963  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.15  dead=None  v=0.40  ω=2.64
# [DBG] d=1.965  br=far  ptr=0  look=25  α_W=0.97  α_G=-2.28  dead=None  v=0.40  ω=2.64
# [DBG] d=1.971  br=far  ptr=0  look=25  α_W=0.98  α_G=-2.44  dead=None  v=0.40  ω=2.66
# [DBG] d=1.978  br=far  ptr=0  look=25  α_W=1.00  α_G=-2.57  dead=None  v=0.40  ω=2.70
# [DBG] d=1.994  br=far  ptr=0  look=25  α_W=1.00  α_G=-2.71  dead=None  v=0.40  ω=2.69
# [DBG] d=2.007  br=far  ptr=0  look=25  α_W=1.02  α_G=-2.86  dead=None  v=0.40  ω=2.73
# [DBG] d=2.026  br=far  ptr=0  look=25  α_W=1.03  α_G=-3.02  dead=None  v=0.40  ω=2.74
# [DBG] d=2.046  br=far  ptr=0  look=25  α_W=1.03  α_G=3.10  dead=None  v=0.40  ω=2.74
# [DBG] d=2.067  br=far  ptr=0  look=25  α_W=1.03  α_G=2.93  dead=None  v=0.40  ω=2.74
# [DBG] d=2.090  br=far  ptr=0  look=25  α_W=1.02  α_G=2.76  dead=None  v=0.40  ω=2.73
# [DBG] d=2.114  br=far  ptr=0  look=25  α_W=1.02  α_G=2.60  dead=None  v=0.40  ω=2.73
# [DBG] d=2.137  br=far  ptr=0  look=25  α_W=1.03  α_G=2.45  dead=None  v=0.40  ω=2.74
# [DBG] d=2.161  br=far  ptr=0  look=25  α_W=1.05  α_G=2.30  dead=None  v=0.40  ω=2.77
# [DBG] d=2.185  br=far  ptr=0  look=25  α_W=1.06  α_G=2.15  dead=None  v=0.40  ω=2.79
# [DBG] d=2.208  br=far  ptr=0  look=25  α_W=1.07  α_G=1.99  dead=None  v=0.40  ω=2.80
# [DBG] d=2.227  br=far  ptr=0  look=25  α_W=1.06  α_G=1.84  dead=None  v=0.40  ω=2.79
# [DBG] d=2.247  br=far  ptr=0  look=25  α_W=1.06  α_G=1.68  dead=None  v=0.40  ω=2.79
# [DBG] d=2.264  br=far  ptr=0  look=25  α_W=1.08  α_G=1.55  dead=None  v=0.40  ω=2.82
# [DBG] d=2.276  br=far  ptr=0  look=25  α_W=1.07  α_G=1.40  dead=None  v=0.40  ω=2.81
# [DBG] d=2.287  br=far  ptr=0  look=25  α_W=1.08  α_G=1.27  dead=None  v=0.40  ω=2.82
# [DBG] d=2.285  br=far  ptr=0  look=25  α_W=1.05  α_G=1.12  dead=None  v=0.40  ω=2.77
# [DBG] d=2.287  br=far  ptr=0  look=25  α_W=1.04  α_G=0.97  dead=None  v=0.40  ω=2.75
# [DBG] d=2.284  br=far  ptr=0  look=25  α_W=1.03  α_G=0.84  dead=None  v=0.40  ω=2.74
# [DBG] d=2.277  br=far  ptr=0  look=25  α_W=1.03  α_G=0.70  dead=None  v=0.40  ω=2.75
# [DBG] d=2.270  br=far  ptr=0  look=25  α_W=1.04  α_G=0.58  dead=None  v=0.40  ω=2.75
# [DBG] d=2.256  br=far  ptr=0  look=25  α_W=1.02  α_G=0.45  dead=None  v=0.40  ω=2.72
# [DBG] d=2.243  br=far  ptr=0  look=25  α_W=1.02  α_G=0.32  dead=None  v=0.40  ω=2.73
# [DBG] d=2.227  br=far  ptr=0  look=25  α_W=1.00  α_G=0.18  dead=None  v=0.40  ω=2.70
# [DBG] d=2.211  br=far  ptr=0  look=25  α_W=0.99  α_G=0.02  dead=None  v=0.40  ω=2.67
# [DBG] d=2.194  br=far  ptr=0  look=25  α_W=0.97  α_G=-0.11  dead=None  v=0.40  ω=2.63

# %%
def analyze_debug(memory: Dict):
    trace = memory.get("debug_trace", [])
    if not trace:
        print("No data")
        return

    # 1) Are you ever hitting the deadband?
    dead_hits = [e for e in trace if e["deadband"]]
    print("Deadband hits:", len(dead_hits), "/", len(trace))

    # 2) Final few entries
    print("\nLAST 10 STEPS:")
    for e in trace[-10:]:
        print(f"d={e['dist']:.3f} br={e['branch']} ptr={e['path_ptr']}"
              f" look={e['look_idx']} α_W={e['alpha_W']:.2f}"
              f" α_G={e['alpha_G']:.2f} dead={e['deadband']}"
              f" v={e['v']:.2f} ω={e['ω']:.2f}")

# %%
analyze_debug(move_option_memory)
