# %%
import sys
import numpy as np
import pybullet as p
import time
import logging
from typing import List, Tuple, Optional, Sequence, Collection, Dict, Any, cast
import random
import json

from predicators.structs import Action, Array, GroundAtom, Object, State, Type, ParameterizedOption
from predicators import utils
from predicators.settings import CFG
from gym.spaces import Box

#Import core environment methods, robot function etc.

from predicators.envs.pybullet_blocks import PyBulletBlocksEnv
from predicators.envs.pybullet_env import PyBulletEnv, create_pybullet_block
from predicators.envs.pybullet_multitable_blocks import PyBulletMultiTableBlocksEnv
from predicators.pybullet_helpers.robots import SingleArmPyBulletRobot
from predicators.pybullet_helpers.robots.mobile_single_arm import MobileSingleArmPyBulletRobot
from predicators.pybullet_helpers.geometry import Pose
from predicators.pybullet_helpers.joint import JointPositions, get_joint_infos, get_joint_positions
from predicators.pybullet_helpers.link import get_link_state, get_link_pose
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
logging.basicConfig(
    level=logging.WARNING,                    
    format="%(asctime)s %(name)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

#Defining test configuration, and overriding some default ones:
CFG.pybullet_robot = "fetch_mobile"
CFG.use_gui = True
CFG.env = "pybullet_multitable_blocks"
#Draws helpful debug lines in the workspace.
#NOT SURE WHETHER TO USE THIS. WILL DECIDE AFTER A COUPLE RUNS.
#CFG.pybullet_draw_debug = True
#Initializing with standard size of blocks.
CFG.blocks_block_size = 0.05
CFG.pybullet_birrt_num_iters = 50
CFG.pybullet_birrt_num_attempts = 10
CFG.pybullet_birrt_smooth_amt = 20
CFG.seed = random.randint(0,10000)
#CFG.seed = 12
#Num of PyBullet physics steps per high-level Action in visualize_action_sequence
CFG.pybullet_sim_steps_per_action = 200

# %%
multitable_env = PyBulletMultiTableBlocksEnv(use_gui=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 multitable_env = PyBulletMultiTableBlocksEnv(use_gui=True)
#
# File ~/projects/predicators/predicators/envs/pybullet_multitable_blocks.py:71, in PyBulletMultiTableBlocksEnv.__init__(self, use_gui, num_tables, blocks_per_table, table_poses, table_workspaces)
#      66 assert len(self._table_poses) == num_tables, f"table_poses length ({len(self._table_poses)})"\
#      67                                                         f"must match num_tables ({num_tables})"
#      68 assert len(self._table_workspaces) == num_tables, f"table_workspaces length({len(self._table_workspaces)})" \
#      69                                                                     f"must match num_tables ({num_tables})"
# ---> 71 super().__init__(use_gui)
#      73 # Create table type and objects
#      74 self._table_type = Type("table", ["pose_x", "pose_y", "pose_z", "id"])
#
# File ~/projects/predicators/predicators/envs/pybullet_env.py:70, in PyBulletEnv.__init__(self, use_gui)
#      66 self._held_obj_id: Optional[int] = None
#      68 # Set up all the static PyBullet content.
#      69 self._physics_client_id, self._pybullet_robot, pybullet_bodies = \
# ---> 70     self.initialize_pybullet(self.using_gui)
#      71 self._store_pybullet_bodies(pybullet_bodies)
#
# File ~/projects/predicators/predicators/envs/pybullet_multitable_blocks.py:165, in PyBulletMultiTableBlocksEnv.initialize_pybullet(cls, using_gui, num_tables, table_poses)
#     157 @classmethod
#     158 def initialize_pybullet(
#     159     cls, using_gui: bool,
#     160     num_tables: int = 3,
#     161     table_poses: Optional[List[Pose3D]] = None
#     162     ) -> Tuple[int, MobileSingleArmPyBulletRobot, Dict[str, Any]]:
#     163     """Initialize pybullet with multiple tables"""
# --> 165     physics_client_id, pybullet_robot, bodies = super().initialize_pybullet(using_gui)
#     167     #Use provided poses or defaults
#     168     poses = table_poses or cls._default_table_poses[:num_tables]
#
# File ~/projects/predicators/predicators/envs/pybullet_env.py:110, in PyBulletEnv.initialize_pybullet(cls, using_gui)
#     103 p.changeDynamics(
#     104             bodyUniqueId=plane_id,
#     105             linkIndex= -1,
#     106             lateralFriction=2.0,   # match your wheels
#     107             physicsClientId=physics_client_id)
#     109 # Load robot.
# --> 110 pybullet_robot = cls._create_pybullet_robot(physics_client_id)
#     112 pybullet_robot.go_home()
#     115 # Set gravity.
#
# File ~/projects/predicators/predicators/envs/pybullet_multitable_blocks.py:239, in PyBulletMultiTableBlocksEnv._create_pybullet_robot(cls, physics_client_id)
#     233 base_pose = (avg_x, avg_y, 0.01)
#     235 #robot_ee_orn = cls.get_robot_ee_home_orn()
#     236 #ee_home = Pose(position=(avg_x+0.5, avg_y, cls.pick_z), orientation=(0.0, 0.0, 0.0, 1.0))
#     237 #print(f"\nEE home:{ee_home}")
#     238 #input()
# --> 239 return create_single_arm_pybullet_robot(CFG.pybullet_robot, physics_client_id)
#
# File ~/projects/predicators/predicators/pybullet_helpers/robots/__init__.py:54, in create_single_arm_pybullet_robot(robot_name, physics_client_id, ee_home_pose)
#      43 # Changing the ee_home_pose for fetch_mobile so that it works with the
#      44 # spawn position defined in _ROBOT_TO_BASE_POSE when IKFast is called for
#      45 # ee_home_pose.
#    (...)
#      50
#      51 #     ee_home_pose = Pose(mobile_fetch_home_position, mobile_fetch_home_orientation)
#      53 if ee_home_pose is None:
# ---> 54     robot_to_ee_orn = CFG.pybullet_robot_ee_orns[CFG.env]
#      55     assert robot_name in robot_to_ee_orn, \
#      56         f"Default home orn not specified for robot {robot_name}."
#      57     ee_orientation = robot_to_ee_orn[robot_name]
#
# AttributeError: 'types.SimpleNamespace' object has no attribute 'env'
