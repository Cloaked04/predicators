# %%
import numpy as np

# %%
def uniform_generator(d):
    while True:
        yield np.random.uniform(size=d)


def halton_generator(d):
    import ghalton
    seed = random.randint(0, 1000)
    #sequencer = ghalton.Halton(d)
    sequencer = ghalton.GeneralizedHalton(d, seed)
    # sequencer.reset()
    while True:
        [weights] = sequencer.get(1)
        yield np.array(weights)


def unit_generator(d, use_halton=False):
    if use_halton:
        try:
            import ghalton
        except ImportError:
            print('ghalton is not installed (https://pypi.org/project/ghalton/)')
            use_halton = False
    return halton_generator(d) if use_halton else uniform_generator(d)


def interval_generator(lower, upper, **kwargs):
    assert len(lower) == len(upper)
    assert np.less(lower, upper).all()  # TODO: equality
    extents = np.array(upper) - np.array(lower)
    for scale in unit_generator(len(lower), **kwargs):
        point = np.array(lower) + scale*extents
        yield point

# %%
a = interval_generator([1,2,3], [999, 999, 9999])

# %%
for gen in a:
    print(gen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for gen in a:
#       2     print(gen)
#
# Cell In[3], line 15, in interval_generator(lower, upper, **kwargs)
#      13 assert np.less(lower, upper).all()  # TODO: equality
#      14 extents = np.array(upper) - np.array(lower)
# ---> 15 for scale in unit_generator(len(lower), **kwargs):
#      16     point = np.array(lower) + scale*extents
#      17     yield point
#
# Cell In[3], line 8, in unit_generator(d, use_halton)
#       6         print('ghalton is not installed (https://pypi.org/project/ghalton/)')
#       7         use_halton = False
# ----> 8 return halton_generator(d) if use_halton else uniform_generator(d)
#
# NameError: name 'uniform_generator' is not defined
